# %%
def readFile():
    d = {}
    with open("/home/medina/SO/traces/gcc.trace") as f:
        for line in f:
           (key, val) = line.split()
           d[key] = val
    return d
processList = readFile()
print(processList)
# Out:
# {'0041f7a0': 'R', '13f5e2c0': 'R', '05e78900': 'R', '004758a0': 'R', '31348900': 'W', '004a30e0': 'R', '0700ff05': 'R', '0049e120': 'R', '004c25f8': 'R', '004c2600': 'R', '3305a5e0': 'W', '05e06600': 'W', '0044e4f8': 'R', '0044e500': 'R', '0044e520': 'R', '0700ff10': 'R', '2f6965a0': 'W', '0044e5c0': 'R', '0044e5e0': 'R', '0044e621': 'R', '31dae640': 'W', '00414f20': 'R', '05f7cf20': 'W', '004bcfc0': 'R', '2774cfc0': 'W', '004696a0': 'R', '00446460': 'R', '31f92120': 'W', '00496ec0': 'R', '004a0c00': 'R', '0049d640': 'R', '004f3df0': 'R', '3d729820': 'W', '00496fb0': 'R', '00496fc0': 'R', '21dd6fc0': 'W', '004a9860': 'R', '004aa4d8': 'R', '004aa4e0': 'R', '004bd000': 'R', '044b71e0': 'R', '04497780': 'R', '004977a0': 'R', '12151660': 'R', '004b3a80': 'R', '05e9ba80': 'W', '31602880': 'W', '004b39c0': 'R', '33b1b9c0': 'W', '004b0ba0': 'R', '004953b0': 'R', '004bd080': 'R', '0785d080': 'W', '05ae74a2': 'W', '004b3900': 'R', '32f53900': 'W', '00497738': 'R', '31a2f720': 'W', '00497740':
# ...

# %%
def hex2bin:
    scale = 16
    num_of_bits = 8
    bin(int(0041f7a0))
